# %% [markdown]
# Data laoding
# 1. Loaded the dataset using panding
# 2. Displayed first 5 rows with df.head()

# %%
import pandas as pd 

#Load the dataset 

df=pd.read_csv("../data/titanic.csv") 

print(df.head())
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age     fare  sibsp  parch
# 0    male  22.0   7.2500      1      0
# 1  female  38.0  71.2833      1      0
# 2  female  26.0   7.9250      0      0
# 3  female  35.0  53.1000      1      0
# 4    male  35.0   8.0500      0      0

# %% [markdown]
# Basic Exploration
#
# 1. Checked data types and missing vlaues with df.info()
# 2. Checked for misssing values
# 3. Calculated summary statistic with df.describe()

# %%
#check info 

df.info()

#checking missing values 

df.isnull().sum()

#summary statistic 

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  714 non-null    int64
#  1   pclass    714 non-null    int64
#  2   name      714 non-null    object
#  3   sex       714 non-null    object
#  4   age       714 non-null    float64
#  5   fare      714 non-null    float64
#  6   sibsp     714 non-null    int64
#  7   parch     714 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 44.8+ KB
#          survived      pclass         age        fare       sibsp       parch
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695   29.699118   34.694514    0.512605    0.431373
# std      0.491460    0.838250   14.526497   52.918930    0.929783    0.853289
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# Survival Rates
#
# 1. count of survived vs not survived
# 2. Survival Rates by gender and passenger class

# %%
survival_rate=df['survived'].mean()
print(f"overall survival rate:{survival_rate:.2f}")
# Out:
# overall survival rate:0.41

# %%
#survival count 

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='survival_status')
plt.title('Survival Count')
plt.show()

# %%
#survival by Gender 

sns.countplot(data=df,x='survived',hue='sex')
plt.title('Survived Count by Gender')
plt.show()

# %%
# Create a new column for labeled survival
df['survival_status'] = df['survived'].map({0: 'Dead', 1: 'Alive'})

# Check
print(df[['survived', 'survival_status']].head())
# Out:
#    survived survival_status
# 0         0            Dead
# 1         1           Alive
# 2         1           Alive
# 3         1           Alive
# 4         0            Dead

# %%
#survival by passenger class 

sns.countplot(data=df,x='pclass',hue='survived')
plt.title('Survival by Passenger Class')
plt.show()

# %%
sns.histplot(data=df,x='age',hue='survived',multiple='stack',bins=30) 
plt.title('Age Distribution by Survival')
plt.show()

# %%
#Fare vs survival 

sns.boxplot(data=df,x='survived',y='fare')
plt.title('Fare vs Survival')
plt.show()

# %% [markdown]
# Visualisation
#
#  Plots created using  Matplotlib and seaborn
#
# 1. Count of survived vs not survived
# 2. Survival by gender
# 3. Survival by passenger class
# 4. Age distribution by survival
# 5. Fare vs survival
